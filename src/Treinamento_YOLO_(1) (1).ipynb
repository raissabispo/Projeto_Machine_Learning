# %% [markdown]
# # Treinamento YOLOv8n — Detecção de Máscaras
#
# ## Objetivo
#
# Treinar e avaliar um modelo YOLOv8n para identificar três situações:
#
# - `mask_weared_incorrect` — pessoa usando a máscara incorretamente
# - `with_mask` — pessoa com máscara
# - `without_mask` — pessoa sem máscara
#
# ### Fluxo do notebook
#
# **Dataset → análise → seleção balanceada → divisão Train/Valid/Test → `data.yaml` → treinamento → teste → exportação dos artefatos**
#
# > **Observação:** o modelo final desta versão é o `best.pt` gerado no segundo treinamento (refinamento final).

# %% [markdown]
# ## 1. Preparação do ambiente
#
# Instalação da biblioteca principal e importação das ferramentas utilizadas no notebook.

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 9.7 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Dataset original
#
# O dataset original é obtido em formato ZIP e extraído no ambiente do Google Colab.
#
# Link do dataset: https://universe.roboflow.com/ai-workspace-yolo-ghcsl/medical-mask-detection/dataset/4?utm_source=chatgpt.com

# %%
arquivo_zip = "/content/Medical Mask Detection.v4i.yolov8.zip"

print("ZIP selecionado:", arquivo_zip)
# Out:
# ZIP selecionado: /content/Medical Mask Detection.v4i.yolov8.zip

# %%
import zipfile
import os

pasta_original = "/content/medical_mask"

if not os.path.exists(pasta_original):

    with zipfile.ZipFile(arquivo_zip, "r") as zip_ref:
        zip_ref.extractall(pasta_original)

    print("Dataset extraído com sucesso!")

else:

    print("A pasta já existe. Extração não necessária.")
# Out:
# Dataset extraído com sucesso!

# %%
print(os.listdir(pasta_original))
# Out:
# ['train', 'README.dataset.txt', 'data.yaml', 'README.roboflow.txt']

# %% [markdown]
# ## 3. Conferência do dataset
#
# Verificação da estrutura, das classes e da quantidade de imagens e labels.

# %%
import yaml

caminho_yaml_original = "/content/medical_mask/data.yaml"

with open(caminho_yaml_original, "r") as arquivo:
    dados_original = yaml.safe_load(arquivo)

print(dados_original)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'test': '../test/images', 'nc': 3, 'names': ['mask_weared_incorrect', 'with_mask', 'without_mask'], 'roboflow': {'workspace': 'ai-workspace-yolo-ghcsl', 'project': 'medical-mask-detection', 'version': 4, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/ai-workspace-yolo-ghcsl/medical-mask-detection/dataset/4'}}

# %%
for id_classe, nome in enumerate(dados_original["names"]):
    print(id_classe, "->", nome)
# Out:
# 0 -> mask_weared_incorrect
# 1 -> with_mask
# 2 -> without_mask

# %%
nomes_classes = {
    0: "mask_weared_incorrect",
    1: "with_mask",
    2: "without_mask"
}

print(nomes_classes)
# Out:
# {0: 'mask_weared_incorrect', 1: 'with_mask', 2: 'without_mask'}

# %%
import os

pasta_train_original = "/content/medical_mask/train"

print(os.listdir(pasta_train_original))
# Out:
# ['images', 'labels']

# %%
pasta_images_original = "/content/medical_mask/train/images"
pasta_labels_original = "/content/medical_mask/train/labels"

quantidade_imagens = len([
    f for f in os.listdir(pasta_images_original)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
])

quantidade_labels = len([
    f for f in os.listdir(pasta_labels_original)
    if f.endswith(".txt")
])

print("Imagens:", quantidade_imagens)
print("Labels:", quantidade_labels)
# Out:
# Imagens: 14442
# Labels: 14442

# %%
from collections import Counter
import os

contador = Counter()

for nome_arquivo in os.listdir(pasta_labels_original):

    if not nome_arquivo.endswith(".txt"):
        continue

    caminho = os.path.join(
        pasta_labels_original,
        nome_arquivo
    )

    with open(caminho, "r") as arquivo:

        for linha in arquivo:

            partes = linha.strip().split()

            if len(partes) == 5:

                id_classe = int(partes[0])

                contador[id_classe] += 1

print("Objetos por classe:\n")

for classe in [0, 1, 2]:

    print(
        f"{classe} -> "
        f"{nomes_classes[classe]}: "
        f"{contador[classe]}"
    )
# Out:
# Objetos por classe:
#
# 0 -> mask_weared_incorrect: 2514
# 1 -> with_mask: 15388
# 2 -> without_mask: 6878

# %% [markdown]
# ## 4. Seleção de imagens para balanceamento
#
# Para reduzir o desequilíbrio entre as classes, são consideradas apenas imagens que possuem **exatamente um objeto**.
#
# Depois, são selecionadas aleatoriamente **2.163 imagens por classe**, com `seed=42` para tornar a seleção reproduzível.

# %%
import os

pasta_labels_original = "/content/medical_mask/train/labels"

imagens_uma_classe_um_objeto = {
    0: [],
    1: [],
    2: []
}

for nome_arquivo in os.listdir(pasta_labels_original):

    if not nome_arquivo.endswith(".txt"):
        continue

    caminho = os.path.join(
        pasta_labels_original,
        nome_arquivo
    )

    with open(caminho, "r") as arquivo:
        linhas = arquivo.readlines()

    linhas_validas = []

    for linha in linhas:

        partes = linha.strip().split()

        if len(partes) == 5:
            linhas_validas.append(partes)

    # Exatamente 1 objeto
    if len(linhas_validas) != 1:
        continue

    classe = int(linhas_validas[0][0])

    if classe in imagens_uma_classe_um_objeto:
        imagens_uma_classe_um_objeto[classe].append(
            nome_arquivo
        )

nomes_classes = {
    0: "mask_weared_incorrect",
    1: "with_mask",
    2: "without_mask"
}

print("Imagens com exatamente 1 objeto:\n")

for classe in [0, 1, 2]:

    print(
        f"{classe} -> "
        f"{nomes_classes[classe]}: "
        f"{len(imagens_uma_classe_um_objeto[classe])}"
    )
# Out:
# Imagens com exatamente 1 objeto:
#
# 0 -> mask_weared_incorrect: 2163
# 1 -> with_mask: 5707
# 2 -> without_mask: 4664

# %% [markdown]
# ## 5. Criação do dataset balanceado

# %%
import os
import shutil

pasta_balanceado_base = "/content/medical_mask_balanceado_base"

if os.path.exists(pasta_balanceado_base):
    shutil.rmtree(pasta_balanceado_base)

for classe in [0, 1, 2]:

    os.makedirs(
        f"{pasta_balanceado_base}/images/{classe}",
        exist_ok=True
    )

    os.makedirs(
        f"{pasta_balanceado_base}/labels/{classe}",
        exist_ok=True
    )

print("Pasta base criada!")
# Out:
# Pasta base criada!

# %%
import random

quantidade_por_classe = 2163

random.seed(42)

selecionadas = {}

for classe in [0, 1, 2]:

    selecionadas[classe] = random.sample(
        imagens_uma_classe_um_objeto[classe],
        quantidade_por_classe
    )

    print(
        nomes_classes[classe],
        ":",
        len(selecionadas[classe])
    )
# Out:
# mask_weared_incorrect : 2163
# with_mask : 2163
# without_mask : 2163

# %%
for classe in [0, 1, 2]:

    for nome_label in selecionadas[classe]:

        # Copiar label
        origem_label = os.path.join(
            pasta_labels_original,
            nome_label
        )

        destino_label = os.path.join(
            pasta_balanceado_base,
            "labels",
            str(classe),
            nome_label
        )

        shutil.copy2(
            origem_label,
            destino_label
        )

        # Procurar imagem
        nome_base = os.path.splitext(nome_label)[0]

        for extensao in [".jpg", ".jpeg", ".png"]:

            nome_imagem = nome_base + extensao

            origem_imagem = os.path.join(
                pasta_images_original,
                nome_imagem
            )

            if os.path.exists(origem_imagem):

                destino_imagem = os.path.join(
                    pasta_balanceado_base,
                    "images",
                    str(classe),
                    nome_imagem
                )

                shutil.copy2(
                    origem_imagem,
                    destino_imagem
                )

                break

print("Imagens e labels copiadas!")
# Out:
# Imagens e labels copiadas!

# %%
import os
import shutil

pasta_dataset = "/content/medical_mask_balanceado"

if os.path.exists(pasta_dataset):
    shutil.rmtree(pasta_dataset)

for parte in ["train", "valid", "test"]:

    os.makedirs(
        f"{pasta_dataset}/{parte}/images",
        exist_ok=True
    )

    os.makedirs(
        f"{pasta_dataset}/{parte}/labels",
        exist_ok=True
    )

print("Estrutura final criada!")
# Out:
# Estrutura final criada!

# %% [markdown]
#  ## 6. Verificação da divisão

# %%
random.seed(42)

for classe in [0, 1, 2]:

    lista = selecionadas[classe].copy()

    random.shuffle(lista)

    train_lista = lista[:1731]

    valid_lista = lista[1731:1731 + 216]

    test_lista = lista[1731 + 216:]

    print(
        "\n",
        nomes_classes[classe]
    )

    print("Train:", len(train_lista))
    print("Valid:", len(valid_lista))
    print("Test:", len(test_lista))
# Out:
#  mask_weared_incorrect
# Train: 1731
# Valid: 216
# Test: 216
#
#  with_mask
# Train: 1731
# Valid: 216
# Test: 216
#
#  without_mask
# Train: 1731
# Valid: 216
# Test: 216

# %%
def copiar_lista(lista, parte):

    for nome_label in lista:

        # -----------------------------
        # LABEL
        # -----------------------------

        origem_label = os.path.join(
            pasta_labels_original,
            nome_label
        )

        destino_label = os.path.join(
            pasta_dataset,
            parte,
            "labels",
            nome_label
        )

        shutil.copy2(
            origem_label,
            destino_label
        )

        # -----------------------------
        # IMAGEM
        # -----------------------------

        nome_base = os.path.splitext(nome_label)[0]

        encontrada = False

        for extensao in [".jpg", ".jpeg", ".png"]:

            nome_imagem = nome_base + extensao

            origem_imagem = os.path.join(
                pasta_images_original,
                nome_imagem
            )

            if os.path.exists(origem_imagem):

                destino_imagem = os.path.join(
                    pasta_dataset,
                    parte,
                    "images",
                    nome_imagem
                )

                shutil.copy2(
                    origem_imagem,
                    destino_imagem
                )

                encontrada = True
                break

        if not encontrada:
            print(
                "Imagem não encontrada:",
                nome_base
            )

# %%
for classe in [0, 1, 2]:

    lista = selecionadas[classe].copy()

    random.seed(42)
    random.shuffle(lista)

    train_lista = lista[:1731]
    valid_lista = lista[1731:1947]
    test_lista = lista[1947:2163]

    copiar_lista(
        train_lista,
        "train"
    )

    copiar_lista(
        valid_lista,
        "valid"
    )

    copiar_lista(
        test_lista,
        "test"
    )

print("Divisão concluída!")
# Out:
# Divisão concluída!

# %%
for parte in ["train", "valid", "test"]:

    pasta = f"{pasta_dataset}/{parte}/images"

    quantidade = len([
        f for f in os.listdir(pasta)
        if f.lower().endswith(
            (".jpg", ".jpeg", ".png")
        )
    ])

    print(
        parte,
        ":",
        quantidade,
        "imagens"
    )
# Out:
# train : 5193 imagens
# valid : 648 imagens
# test : 648 imagens

# %%
from collections import Counter

for parte in ["train", "valid", "test"]:

    pasta_labels = (
        f"{pasta_dataset}/{parte}/labels"
    )

    contador = Counter()

    for nome_arquivo in os.listdir(pasta_labels):

        if not nome_arquivo.endswith(".txt"):
            continue

        caminho = os.path.join(
            pasta_labels,
            nome_arquivo
        )

        with open(caminho, "r") as arquivo:

            linhas = arquivo.readlines()

        for linha in linhas:

            partes = linha.strip().split()

            if len(partes) == 5:

                contador[int(partes[0])] += 1

    print(f"\n{parte.upper()}")

    for classe in [0, 1, 2]:

        print(
            nomes_classes[classe],
            ":",
            contador[classe]
        )
# Out:
# TRAIN
# mask_weared_incorrect : 1731
# with_mask : 1731
# without_mask : 1731
#
# VALID
# mask_weared_incorrect : 216
# with_mask : 216
# without_mask : 216
#
# TEST
# mask_weared_incorrect : 216
# with_mask : 216
# without_mask : 216

# %% [markdown]
# ## 7. Configuração do YOLO
#
# Criação do `data.yaml` usado no treinamento.

# %%
data_yaml = """
path: /content/medical_mask_balanceado

train: train/images
val: valid/images
test: test/images

names:
  0: mask_weared_incorrect
  1: with_mask
  2: without_mask
"""

with open(
    f"{pasta_dataset}/data.yaml",
    "w"
) as arquivo:

    arquivo.write(data_yaml.strip())

print("data.yaml criado!")
# Out:
# data.yaml criado!

# %%
print(
    open(
        f"{pasta_dataset}/data.yaml"
    ).read()
)
# Out:
# path: /content/medical_mask_balanceado
#
# train: train/images
# val: valid/images
# test: test/images
#
# names:
#   0: mask_weared_incorrect
#   1: with_mask
#   2: without_mask

# %% [markdown]
# ## 8. Treinamento.
#
# Treinamento do YOLOv8n pré-treinado com o dataset balanceado.

# %%
from ultralytics import YOLO

modelo_balanceado_final = YOLO(
    "yolov8n.pt"
)

print("YOLOv8n carregado!")
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 108.1MB/s 0.1s
# YOLOv8n carregado!

# %%
resultado_final = modelo_balanceado_final.train(
    data="/content/medical_mask_balanceado/data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    device=0,
    project="/content/runs/mask_balanceado_final",
    name="yolov8n_mask_balanceado"
)
# Out:
# Ultralytics 8.4.157 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/medical_mask_balanceado/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov8n_mask_balanceado, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs/mask_balanceado_final, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/mask_balanceado_final/yolov8n_mask_balanceado, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 25.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'weights/yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 84.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1482.7±1034.8 MB/s, size: 67.9 KB)
# train: Scanning /content/medical_mask_balanceado/train/labels... 5193 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5193/5193 2.2Kit/s 2.3s
# train: New cache created: /content/medical_mask_balanceado/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 322.9±137.9 MB/s, size: 37.6 KB)
# val: Scanning /content/medical_mask_balanceado/valid/labels... 648 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 648/648 894.3it/s 0.7s
# val: New cache created: /content/medical_mask_balanceado/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/mask_balanceado_final/yolov8n_mask_balanceado/labels.jpg...
# Using 5193 train, 648 val images for fraction=1.0 at imgsz=640
# Using 2 dataloader workers
# Logging results to /content/runs/mask_balanceado_final/yolov8n_mask_balanceado
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.02G      1.279      2.044      1.631         23        640: 100% ━━━━━━━━━━━━ 325/325 4.0it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.3it/s 4.9s
#                    all        648        648      0.849      0.828      0.875      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.57G       1.28      1.351      1.585         22        640: 100% ━━━━━━━━━━━━ 325/325 4.3it/s 1:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.1s
#                    all        648        648      0.831      0.785      0.841      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.57G       1.29      1.197      1.569         21        640: 100% ━━━━━━━━━━━━ 325/325 4.3it/s 1:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.3it/s 4.8s
#                    all        648        648       0.83      0.765      0.862      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.57G       1.26       1.08      1.554         18        640: 100% ━━━━━━━━━━━━ 325/325 4.2it/s 1:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.8it/s 5.5s
#                    all        648        648      0.896      0.862      0.913      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.57G      1.241      1.025       1.53         16        640: 100% ━━━━━━━━━━━━ 325/325 4.5it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.2it/s 5.0s
#                    all        648        648      0.906      0.917      0.936      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.57G      1.209     0.9664      1.511         18        640: 100% ━━━━━━━━━━━━ 325/325 4.5it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.2s
#                    all        648        648       0.93      0.895       0.94      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.57G      1.188     0.9204      1.488         18        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.2it/s 5.0s
#                    all        648        648      0.932      0.945      0.974      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.57G       1.18     0.9003      1.478         18        640: 100% ━━━━━━━━━━━━ 325/325 4.5it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.7it/s 5.8s
#                    all        648        648      0.954      0.937      0.974      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.57G      1.172     0.8664      1.475         18        640: 100% ━━━━━━━━━━━━ 325/325 4.5it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.1s
#                    all        648        648      0.961       0.94      0.975      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.57G      1.149     0.8588      1.461         22        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.3it/s 6.4s
#                    all        648        648      0.964      0.951      0.971      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.57G      1.131     0.8304      1.451         21        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.2s
#                    all        648        648      0.964      0.949      0.977       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.57G      1.136     0.8074      1.445         23        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.3it/s 6.4s
#                    all        648        648      0.985       0.96      0.985       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.57G      1.117     0.7978      1.437         23        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.3s
#                    all        648        648      0.963      0.962      0.979      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      2.57G       1.11     0.7765       1.43         22        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.6it/s 5.9s
#                    all        648        648      0.965      0.944      0.974      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.57G      1.093     0.7541      1.418         19        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.1s
#                    all        648        648      0.975      0.962      0.984      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.57G      1.085     0.7418      1.414         21        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.2it/s 6.6s
#                    all        648        648      0.969      0.968      0.987      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.57G      1.078     0.7311      1.411         22        640: 100% ━━━━━━━━━━━━ 325/325 4.5it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.1s
#                    all        648        648      0.974      0.971      0.981      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.57G      1.069      0.719      1.399         22        640: 100% ━━━━━━━━━━━━ 325/325 4.5it/s 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.1s
#                    all        648        648      0.982       0.98      0.986      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.57G      1.074     0.7255      1.407         26        640: 100% ━━━━━━━━━━━━ 325/325 4.4it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.4it/s 4.8s
#                    all        648        648      0.982      0.974      0.987       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      2.57G      1.071     0.7032      1.399         24        640: 100% ━━━━━━━━━━━━ 325/325 4.5it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.8it/s 5.5s
#                    all        648        648      0.977      0.972      0.984      0.635
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.57G      1.077     0.5051      1.536          9        640: 100% ━━━━━━━━━━━━ 325/325 4.8it/s 1:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.5it/s 4.7s
#                    all        648        648      0.976      0.971      0.986      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.57G      1.053     0.4983      1.535          9        640: 100% ━━━━━━━━━━━━ 325/325 5.0it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.5it/s 5.9s
#                    all        648        648      0.978      0.978      0.987      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.57G      1.031     0.4723      1.508          9        640: 100% ━━━━━━━━━━━━ 325/325 5.0it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.4it/s 4.8s
#                    all        648        648      0.981      0.971      0.983      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.57G      1.019     0.4593      1.499          9        640: 100% ━━━━━━━━━━━━ 325/325 5.0it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.2it/s 4.9s
#                    all        648        648      0.984      0.985      0.988      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.57G      1.001     0.4536      1.477          9        640: 100% ━━━━━━━━━━━━ 325/325 5.0it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.2s
#                    all        648        648      0.973      0.986      0.985       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.57G     0.9766     0.4386       1.47          9        640: 100% ━━━━━━━━━━━━ 325/325 5.1it/s 1:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.1s
#                    all        648        648      0.978      0.977      0.988      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.57G     0.9735     0.4322      1.458          9        640: 100% ━━━━━━━━━━━━ 325/325 5.0it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.1s
#                    all        648        648      0.981      0.975      0.989       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.57G     0.9549     0.4232       1.45          9        640: 100% ━━━━━━━━━━━━ 325/325 5.0it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.3it/s 4.9s
#                    all        648        648       0.98      0.986      0.988      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.57G     0.9378     0.4136       1.44          9        640: 100% ━━━━━━━━━━━━ 325/325 5.0it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.2s
#                    all        648        648      0.983      0.984      0.987      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.57G     0.9271     0.4145      1.427          9        640: 100% ━━━━━━━━━━━━ 325/325 4.9it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 4.3it/s 4.9s
#                    all        648        648      0.984      0.988      0.987      0.679
#
# 30 epochs completed in 0.643 hours.
# Optimizer stripped from /content/runs/mask_balanceado_final/yolov8n_mask_balanceado/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/mask_balanceado_final/yolov8n_mask_balanceado/weights/best.pt, 6.2MB
#
# Validating /content/runs/mask_balanceado_final/yolov8n_mask_balanceado/weights/best.pt...
# Ultralytics 8.4.157 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 2.5it/s 8.3s
#                    all        648        648      0.985      0.988      0.987      0.679
#  mask_weared_incorrect        216        216      0.989      0.986      0.983      0.647
#              with_mask        216        216      0.969      0.986      0.983      0.706
#           without_mask        216        216      0.997      0.991      0.995      0.683
# Speed: 1.2ms preprocess, 2.8ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /content/runs/mask_balanceado_final/yolov8n_mask_balanceado

# %%
import shutil
import os

origem = (
    "/content/runs/mask_balanceado_final/"
    "yolov8n_mask_balanceado/weights/best.pt"
)

destino = "/content/best_mask_balanceado_final.pt"

shutil.copy2(origem, destino)

print("Modelo salvo em:")
print(destino)

print("Existe?", os.path.exists(destino))
# Out:
# Modelo salvo em:
# /content/best_mask_balanceado_final.pt
# Existe? True

# %%
from ultralytics import YOLO

modelo_final = YOLO("/content/best_mask_balanceado_final.pt")

print("Modelo final carregado com sucesso!")
# Out:
# Modelo final carregado com sucesso!

# %%
import os

tamanho_mb = (
    os.path.getsize(destino)
    / (1024 ** 2)
)

print(
    f"Tamanho do modelo: {tamanho_mb:.2f} MB"
)
# Out:
# Tamanho do modelo: 5.96 MB

# %% [markdown]
# ## 09. Avaliação no conjunto de teste

# %%
from ultralytics import YOLO

modelo_final = YOLO("/content/best_mask_balanceado_final.pt")

print("Modelo final carregado com sucesso!")
# Out:
# Modelo final carregado com sucesso!

# %%
metricas_teste = modelo_final.val(
    data="/content/medical_mask_balanceado/data.yaml",
    split="test"
)
# Out:
# Ultralytics 8.4.157 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 624.0±389.8 MB/s, size: 36.3 KB)
# val: Scanning /content/medical_mask_balanceado/test/labels... 648 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 648/648 857.0it/s 0.8s
# val: New cache created: /content/medical_mask_balanceado/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 4.2it/s 9.7s
#                    all        648        648      0.985      0.986      0.991      0.688
#  mask_weared_incorrect        216        216      0.985      0.977      0.991      0.639
#              with_mask        216        216      0.977      0.986      0.989      0.731
#           without_mask        216        216      0.993      0.995      0.994      0.692
# Speed: 1.9ms preprocess, 4.2ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /content/runs/detect/val

# %%
print("=== MÉTRICAS FINAIS ===")
print(f"Precisão: {metricas_teste.box.mp:.4f}")
print(f"Recall: {metricas_teste.box.mr:.4f}")
print(f"mAP50: {metricas_teste.box.map50:.4f}")
print(f"mAP50-95: {metricas_teste.box.map:.4f}")
# Out:
# === MÉTRICAS FINAIS ===
# Precisão: 0.9849
# Recall: 0.9861
# mAP50: 0.9914
# mAP50-95: 0.6875

# %%
import os

tamanho_mb = (
    os.path.getsize(destino)
    / (1024 ** 2)
)

print(f"Tamanho do modelo: {tamanho_mb:.2f} MB")
# Out:
# Tamanho do modelo: 5.96 MB

# %%
from google.colab import files

files.download("/content/best_mask_balanceado_final.pt")

# %%
from ultralytics import YOLO

modelo_final = YOLO(
    "/content/best_mask_balanceado_final.pt"
)

print("Modelo carregado com sucesso!")
# Out:
# Modelo carregado com sucesso!

# %%
from ultralytics import YOLO
import cv2
import os
import matplotlib.pyplot as plt

modelo = YOLO("/content/best_mask_balanceado_final.pt")

pasta_teste = "/content/medical_mask_balanceado/test/images"

arquivos = sorted([
    f for f in os.listdir(pasta_teste)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
])

imagem_path = os.path.join(pasta_teste, arquivos[0])

resultado = modelo(imagem_path, conf=0.25)[0]

imagem_resultado = resultado.plot()

imagem_resultado = cv2.cvtColor(
    imagem_resultado,
    cv2.COLOR_BGR2RGB
)

plt.figure(figsize=(10, 8))
plt.imshow(imagem_resultado)
plt.axis("off")
plt.show()

print("Imagem testada:", arquivos[0])
# Out:
# image 1/1 /content/medical_mask_balanceado/test/images/000000003_127-jpg_jpg.rf.ff7218ac64961d4a5a9763fbabefb98d.jpg: 640x640 1 without_mask, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Imagem testada: 000000003_127-jpg_jpg.rf.ff7218ac64961d4a5a9763fbabefb98d.jpg

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
import cv2
import os

# Caminho do modelo
modelo = YOLO("best_mask_balanceado_final.pt")

# Caminho da imagem
imagem = cv2.imread("img.jpg")

if imagem is None:
    print("Erro: não foi possível abrir a imagem.")
else:
    # Faz a previsão
    resultado = modelo(imagem, conf=0.25)

    # Desenha as caixas
    imagem_resultado = resultado[0].plot()

    # Mostra no Colab
    cv2_imshow(imagem_resultado)
# Out:
# 0: 640x480 1 with_mask, 5.9ms
# Speed: 2.9ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=959x1280>

# %%
# ============================================
# FASE 11 — EXPORTAÇÃO DE ARTEFATOS
# ============================================

import os
import shutil
import json

# Pasta de artefatos
pasta_artifacts = "/content/artifacts"
os.makedirs(pasta_artifacts, exist_ok=True)

# ------------------------------------------------
# 1. MODELO FINAL
# ------------------------------------------------

modelo_origem = "/content/best_mask_balanceado_final.pt"
modelo_destino = os.path.join(
    pasta_artifacts,
    "best_mask_balanceado_final.pt"
)

if not os.path.exists(modelo_origem):
    raise FileNotFoundError(
        f"Modelo não encontrado: {modelo_origem}"
    )

shutil.copy2(
    modelo_origem,
    modelo_destino
)

# ------------------------------------------------
# 2. CONFIGURAÇÃO DO DATASET
# ------------------------------------------------

yaml_origem = "/content/medical_mask_balanceado/data.yaml"
yaml_destino = os.path.join(
    pasta_artifacts,
    "data.yaml"
)

if os.path.exists(yaml_origem):
    shutil.copy2(
        yaml_origem,
        yaml_destino
    )

# ------------------------------------------------
# 3. CONFIGURAÇÃO DO EXPERIMENTO
# ------------------------------------------------

config = {
    "modelo": "YOLOv8n",
    "dataset": "Medical Mask Detection",
    "classes": [
        "mask_weared_incorrect",
        "with_mask",
        "without_mask"
    ],
    "epochs": 30,
    "imgsz": 640,
    "batch": 16,
    "device": "GPU",
    "divisao_dataset": {
        "treino": 5193,
        "validacao": 648,
        "teste": 648
    }
}

with open(
    os.path.join(pasta_artifacts, "config.json"),
    "w",
    encoding="utf-8"
) as arquivo:
    json.dump(
        config,
        arquivo,
        indent=4,
        ensure_ascii=False
    )

# ------------------------------------------------
# 4. MÉTRICAS FINAIS
# ------------------------------------------------

metricas = {
    "precisao": float(metricas_teste.box.mp),
    "recall": float(metricas_teste.box.mr),
    "mAP50": float(metricas_teste.box.map50),
    "mAP50_95": float(metricas_teste.box.map),
    "imagens_teste": 648
}

with open(
    os.path.join(pasta_artifacts, "metrics.json"),
    "w",
    encoding="utf-8"
) as arquivo:
    json.dump(
        metricas,
        arquivo,
        indent=4,
        ensure_ascii=False
    )

# ------------------------------------------------
# 5. RELATÓRIO DO EXPERIMENTO
# ------------------------------------------------

relatorio = {
    "modelo": "YOLOv8n",
    "tipo": "Detecção de objetos",
    "aplicacao": "Detecção de máscaras",
    "classes": [
        "mask_weared_incorrect",
        "with_mask",
        "without_mask"
    ],
    "dataset": {
        "total_imagens_balanceadas": 6489,
        "treino": 5193,
        "validacao": 648,
        "teste": 648
    },
    "treinamento": {
        "epocas": 30,
        "imgsz": 640,
        "batch": 16,
        "GPU": True
    },
    "avaliacao": metricas
}

with open(
    os.path.join(pasta_artifacts, "training_report.json"),
    "w",
    encoding="utf-8"
) as arquivo:
    json.dump(
        relatorio,
        arquivo,
        indent=4,
        ensure_ascii=False
    )

# ------------------------------------------------
# 6. CHECKLIST FINAL
# ------------------------------------------------

print("======================================")
print("FASE 11 — ARTEFATOS EXPORTADOS")
print("======================================")

for arquivo in sorted(os.listdir(pasta_artifacts)):
    caminho = os.path.join(
        pasta_artifacts,
        arquivo
    )

    tamanho_mb = os.path.getsize(caminho) / (1024 ** 2)

    print(
        f"✓ {arquivo} — {tamanho_mb:.2f} MB"
    )

print("======================================")
print("Exportação concluída!")
print("Pasta:", pasta_artifacts)
# Out:
# ======================================
# FASE 11 — ARTEFATOS EXPORTADOS
# ======================================
# ✓ best_mask_balanceado_final.pt — 5.96 MB
# ✓ config.json — 0.00 MB
# ✓ data.yaml — 0.00 MB
# ✓ metrics.json — 0.00 MB
# ✓ training_report.json — 0.00 MB
# ======================================
# Exportação concluída!
# Pasta: /content/artifacts
